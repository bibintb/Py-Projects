# %%
import pandas as pd  

url = 'https://en.wikipedia.org/wiki/Comparison_of_deep-learning_software'  
dfs = pd.read_html(url)   

print(len(dfs))
# Out:
# 2

# %%
print(dfs[0])
# Out:
#                                      Software  ...  Actively developed
# 0                                       BigDL  ...                 NaN
# 1                                       Caffe  ...               No[5]
# 2                                     Chainer  ...               No[6]
# 3                              Deeplearning4j  ...                 Yes
# 4                                        Dlib  ...                 NaN
# 5                                        Flux  ...                 Yes
# 6   Intel Data Analytics Acceleration Library  ...                 NaN
# 7                   Intel Math Kernel Library  ...                 NaN
# 8                                       Keras  ...                 Yes
# 9              MATLAB + Deep Learning Toolbox  ...                 Yes
# 10         Microsoft Cognitive Toolkit (CNTK)  ...              No[36]
# 11                               Apache MXNet  ...                 Yes
# ...

# %%
df = dfs[0]

# %%
df
# Out:
#                                      Software  ...  Actively developed
# 0                                       BigDL  ...                 NaN
# 1                                       Caffe  ...               No[5]
# 2                                     Chainer  ...               No[6]
# 3                              Deeplearning4j  ...                 Yes
# 4                                        Dlib  ...                 NaN
# 5                                        Flux  ...                 Yes
# 6   Intel Data Analytics Acceleration Library  ...                 NaN
# 7                   Intel Math Kernel Library  ...                 NaN
# 8                                       Keras  ...                 Yes
# 9              MATLAB + Deep Learning Toolbox  ...                 Yes
# 10         Microsoft Cognitive Toolkit (CNTK)  ...              No[36]
# 11                               Apache MXNet  ...                 Yes
# ...

# %%
df.to_excel('mllibrary.xlsx')
