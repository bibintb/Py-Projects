# %%
import pandas as pd   # importing pandas

url = 'https://en.wikipedia.org/wiki/History_of_Python'  # web page url
dfs = pd.read_html(url)   # Extract table 

print(len(dfs))
# Out:
# 1

# %%
print(dfs[0])
# Out:
#                                               Version  \
# 0                                                 0.9
# 1                                                 1.0
# 2                                                 1.1
# 3                                                 1.2
# 4                                                 1.3
# 5                                                 1.4
# 6                                                 1.5
# 7                                                 1.6
# 8                                                 2.0
# 9                                                 2.1
# 10                                                2.2
# 11                                                2.3
# 12                                                2.4
# 13                                                2.5
# 14                                                2.6
# 15                                                2.7
# ...

# %%
df = dfs[0]   # Get first table

# %%
df2 = df[['Version','Release date']]    # Extract columns
print(df2)
# Out:
#                                               Version  \
# 0                                                 0.9
# 1                                                 1.0
# 2                                                 1.1
# 3                                                 1.2
# 4                                                 1.3
# 5                                                 1.4
# 6                                                 1.5
# 7                                                 1.6
# 8                                                 2.0
# 9                                                 2.1
# 10                                                2.2
# 11                                                2.3
# 12                                                2.4
# 13                                                2.5
# 14                                                2.6
# 15                                                2.7
# ...

# %%
df2.to_excel('python.xlsx')   # Write dataframe to excel

# %%
df2
# Out:
#                                               Version  \
# 0                                                 0.9
# 1                                                 1.0
# 2                                                 1.1
# 3                                                 1.2
# 4                                                 1.3
# 5                                                 1.4
# 6                                                 1.5
# 7                                                 1.6
# 8                                                 2.0
# 9                                                 2.1
# 10                                                2.2
# 11                                                2.3
# 12                                                2.4
# 13                                                2.5
# 14                                                2.6
# 15                                                2.7
# ...
