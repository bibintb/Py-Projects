# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('https://query1.finance.yahoo.com/v7/finance/download/GOOG?period1=1579365747&period2=1610988147&interval=1d&events=history&includeAdjustedClose=true')

# %%
df
# Out:
#            Date         Open         High  ...        Close    Adj Close   Volume
# 0    2020-01-21  1479.119995  1491.849976  ...  1484.400024  1484.400024  2036700
# 1    2020-01-22  1491.000000  1503.213989  ...  1485.949951  1485.949951  1610800
# 2    2020-01-23  1487.640015  1495.520020  ...  1486.650024  1486.650024  1351200
# 3    2020-01-24  1493.589966  1495.494995  ...  1466.709961  1466.709961  1784600
# 4    2020-01-27  1431.000000  1438.069946  ...  1433.900024  1433.900024  1755200
# ..          ...          ...          ...  ...          ...          ...      ...
# 246  2021-01-11  1786.069946  1794.314941  ...  1766.719971  1766.719971  1209700
# 247  2021-01-12  1753.920044  1778.040039  ...  1746.550049  1746.550049  1357700
# 248  2021-01-13  1738.579956  1765.035034  ...  1754.400024  1754.400024  1094100
# 249  2021-01-14  1753.619995  1775.010010  ...  1740.180054  1740.180054  1179500
# ...

# %%
x = df['Close']   #  x object, which contains the daily close price of the stock.

# %%
returns = x.pct_change(1).dropna()

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(returns,bins="rice",label="Daily close price") # histogram of returns.
plt.legend()
plt.show()

# %%
plt.boxplot(returns,labels=["Daily close price"])  #  a boxplot
plt.show()

# %%
plt.plot(returns) # Volatility
plt.xlabel("Time")
plt.ylabel("Daily returns")
plt.show()

# %%
plt.plot(returns.rolling(20).std()) 
plt.xlabel("Time")
plt.ylabel("20-days rolling standard deviation")
plt.show()

# %%
from statsmodels.graphics.tsaplots import plot_pacf

# %%
plot_pacf(returns,lags=20)
